# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import glob
import cv2 as cv
import os

## 데이터 증식

step = 5
kernelSize = 3
size = 100
angleRange = 180
angleRange //= 2

## 프로젝트 파일
path = 'D:\Project 2'

os.chdir(path)

## 이미지 파일
path += '\svgtopng\\'

emotions = list('negative,positive'.split(','))
emotions2 = list([['\\angry','\\sad'],['\\happy']])

finalEmotions = []
for i in range(len(emotions)):
    for j in emotions2[i]:
        finalEmotions.append(emotions[i]+j)
        

for emotion in finalEmotions:
    
    newPath = path + emotion
    files = glob.glob(newPath + '\*.jpg')
    removeFiles = [i for i in files if len(i.split('_')) != 1]
    files = [i for i in files if len(i.split('_')) == 1]
    
    for f in removeFiles:
        os.remove(f)
        
    #continue
    for f in files:
        
        
        img = Image.open(f)
        img = img.convert('L')
        img = np.asarray(img)
        img = cv.resize(src=img, dsize=(size,size))
        blurredImg = cv.GaussianBlur(img, (kernelSize, kernelSize), 0)
        
        # MEDIUM
        processed = cv.Canny(blurredImg, 30, 150)
       
        title, ext = os.path.splitext(f)
        
        cv.imwrite(title + '_resized' + ext, processed)

        center = (size//2,size//2)
        scale = 1.0
        
        for i in range(-angleRange,angleRange+1,step):
            if i == 0:
                continue
            mtx = cv.getRotationMatrix2D(center, i, scale)
            alpha = i * step# if i >= 0 else (360 - step*i)
            img2 = cv.warpAffine(processed, mtx, (size,size))
            cv.imwrite(title + "_resized_%d" % (i) + ext, img2)
# Out:
# C:\Users\user\.conda\envs\dl_study\lib\site-packages\PIL\Image.py:974: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import cv2 as cv
import os

## 데이터 증식

#step = 1
maxData = 300

path = 'D:\Project 2'

os.chdir(path)

path += '\svgtopng\\'



emotions = list('negative,positive'.split(','))
emotions2 = list([['\\angry','\\sad'],['\\happy']])

finalEmotions = []
for i in range(len(emotions)):
    for j in emotions2[i]:
        finalEmotions.append(emotions[i]+j)

xFiles = []
y = []
for i in range(len(emotions)):
    
    newPath = path + emotions[i]
    
    for j in emotions2[i]:
        
        files = glob.glob(newPath + j + '\*.jpg')
        files = [j for j in files if len(j.split('_')) != 1]
        #files = files[::2]
        xFiles.extend(files)
        y.extend([emotions[i]]*len(files))
    
y = pd.Series(y)
y = pd.get_dummies(y,prefix='y',prefix_sep="_").astype('int32')

#y = [1 if i == 'positive' else 0 for i in y]

y = np.array(y).astype('int32')
X = []
i = 0
for f in xFiles:
    
    img = cv.imread(f, cv.IMREAD_GRAYSCALE)
    #img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    #img = img.resize((49,49))
    img = np.asarray(img)
    img = img.astype('float32') / 255
    #img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
     #img = img.convert('RGBA')
    #img = img.convert("A")
    #img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    X.append(img)

#import tensorflow.keras
import numpy as np
#from tensorflow.keras.utils import to_categorical

# 입력과 출력 지정하기 
nb_classes = len(emotions) # 레이블 수
X = np.array(X)
X = X.reshape(-1, size,size,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   test_size=0.33,
                                                   random_state=777,
                                                   stratify=y)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                 test_size=0.2,
                                                 random_state=777,
                                                 stratify=y_train)

# %%
X.shape
# Out:
# (5994, 100, 100, 1)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam

# CNN 모델 정의하기
model = Sequential([
    Conv2D(32, kernel_size=(3,3), activation='relu',input_shape=(size,size, 1)),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
        
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    
        
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(nb_classes,activation='softmax')
        
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 98, 98, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 44, 44, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 64)        0
# ...

# %%
model.compile(loss='categorical_crossentropy',
             optimizer=Adam(1e-4),
             metrics=['accuracy'])

# %%
hist = model.fit(X_train,y_train, 
         batch_size=16,
         epochs=10,
         verbose=1,
         validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 201/201 [==============================] - 112s 553ms/step - loss: 0.6817 - accuracy: 0.5604 - val_loss: 0.6759 - val_accuracy: 0.5629
# Epoch 2/10
# 201/201 [==============================] - 110s 546ms/step - loss: 0.6563 - accuracy: 0.5918 - val_loss: 0.6536 - val_accuracy: 0.6090
# Epoch 3/10
# 201/201 [==============================] - 122s 606ms/step - loss: 0.6061 - accuracy: 0.6768 - val_loss: 0.5935 - val_accuracy: 0.7086
# Epoch 4/10
# 201/201 [==============================] - 114s 567ms/step - loss: 0.5051 - accuracy: 0.7450 - val_loss: 0.5289 - val_accuracy: 0.7497
# Epoch 5/10
# 201/201 [==============================] - 108s 536ms/step - loss: 0.3935 - accuracy: 0.8250 - val_loss: 0.4562 - val_accuracy: 0.7920
# Epoch 6/10
# 201/201 [==============================] - 107s 532ms/step - loss: 0.2593 - accuracy: 0.8938 - val_loss: 0.3763 - val_accuracy: 0.8418
# Epoch 7/10
# ...

# %%
# 모델 평가하기 
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 62/62 [==============================] - 13s 216ms/step - loss: 0.2517 - accuracy: 0.9207
# 정답률= 0.9206669926643372 loss= 0.2516513764858246

# %%
modelJSON = model.to_json()
with open (path+"modelNegativePositive.json", "w") as json_file:
    json_file.write(modelJSON)
model.save_weights(path+"\\modelNegativePositive.h5")

jsonFile = open(path+'modelNegativePositive.json','r')
loadedModel = jsonFile.read()
jsonFile.close()

from keras.models import model_from_json
loadedModel = model_from_json(loadedModel)
loadedModel.load_weights("modelNegativePositive.h5")

loadedModel.compile(loss='categorical_crossentropy', optimizer=Adam(1e-4), metrics=['accuracy'])
score = loadedModel.evaluate(X_test, y_test, verbose=1)
# Out:
# 62/62 [==============================] - 14s 219ms/step - loss: 0.2492 - accuracy: 0.9247

# %%
from PIL import Image

image = Image.open(path +'trial3.png')
image = image.convert('L')
image = image.resize((size,size))
image.save(path + 'dummy.png')
image = np.array(image)
image = ~image
plt.imshow(image)
imarray = np.array(image).astype('float32') / 255
# Out:
# (100, 100)

# %%
X_test2 = np.array(imarray)
X_test2 = X_test2.reshape(-1,size,size,1)

y_test2 = model.predict(X_test2)
index = np.argmax(y_test2)
emotions[index]
# Out:
# array([[0.0664143 , 0.93358564]], dtype=float32)

# %%
sum(y[:,0])
# Out:
# 3108

# %%
sum(y[:,1])
# Out:
# 2886

# %%
# 학습 상태를 그래프로 그리기 
import matplotlib.pyplot as plt

his_dict = hist.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 학습 및 데트스 손실(loss) 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['accuracy']
val_acc = his_dict['val_accuracy']

# 학습 및 데이타 정확도(accuracy) 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()
fig.savefig(path + 'modelNegativePositive.png')
